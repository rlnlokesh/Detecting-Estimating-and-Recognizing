# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Access Google Drive Folder
import os
os.chdir("gdrive/MyDrive")

# %%
# Create YOLOv8 root folder
# !mkdir yolov8-architecture

# %%
# Go to YOLOv8 root folder
# %cd yolov8-architecture
# Out:
# /content/gdrive/MyDrive/yolov8-architecture

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
# %cd data
# Out:
# /content/gdrive/MyDrive/yolov8-architecture/data

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="otDrIn59PC0DyySoxkKt")
project = rf.workspace("balu-c64f7").project("inria-wiug2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/yolov8-architecture

# %%
# Training a Modified Model (Medium Objects)
# !yolo detect train model=yolov8.yaml data=data/inria-1/data.yaml workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8_inria
# Out:
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
